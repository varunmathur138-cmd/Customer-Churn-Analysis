# %% [markdown]
# ## BUSINESS PROBLEM

# %%
# # A telecom company is experiencing customer churn, where customers discontinue their services.
# High churn reduces revenue and increases customer acquisition costs.

# # The objective of this project is to analyze customer demographics, subscription plans, payment behavior, service usage,
# and support interactions to identify the major factors associated with customer churn and provide data-driven recommendations to improve custom

# %% [markdown]
# ## OBJECTIVES

# %%
# - Calculate customer churn rate.
# - Identify customer segments with high churn.
# - Analyze payment behaviour.
# - Study customer tenure.
# - Analyze customer support tickets.
# - Compare churn across plans.
# - Generate business insights.

# %% [markdown]
# ## SCOPE

# %%
# The project focuses on descriptive and diagnostic analytics using Python.

# Machine Learning models are intentionally excluded.
# The analysis will be performed using:

# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
