# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customers = pd.read_csv(r"C:\Users\hp\Desktop\customer-churn-analysis-python\data\raw_data\customers.csv")
plans = pd.read_csv("rC:\Users\hp\Desktop\customer-churn-analysis-python\data\raw_data\plans.csv")
transactions = pd.read_csv(r"C:\Users\hp\Desktop\customer-churn-analysis-python\data\raw_data\transactions.csv")
support = pd.read_csv("rC:\Users\hp\Desktop\customer-churn-analysis-python\data\raw_data\support.csv")
customer_usage = pd.read_csv("rC:\Users\hp\Desktop\customer-churn-analysis-python\data\raw_data\")
